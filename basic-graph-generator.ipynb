# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
## Simple plotting
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]
plt.plot(x, y)
plt.title("2D Plot")
# Out:
# Text(0.5, 1.0, '2D Plot')

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
## Pyplot API

## Univariate Plotting - Numerical
data = {
    "Salary": [50000, 60000, 55000, 70000, 65000, 80000, 72000, 68000, 75000, 62000]
}

data_frame = pd.DataFrame(data)

# print first 5 records of data
data_frame.head()
# Out:
#    Salary
# 0   50000
# 1   60000
# 2   55000
# 3   70000
# 4   65000

# %%
## Check shape of data
data_frame.shape
# Out:
# (10, 1)
